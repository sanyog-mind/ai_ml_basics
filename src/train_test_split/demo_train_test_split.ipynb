# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import os

# %%
base_dir = os.path.abspath(os.path.join('..', 'csv'))

file_path = os.path.join(base_dir, 'train_test_split_carprices.csv')

df = pd.read_csv(file_path)
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
plt.scatter(df["Mileage"], df["Sell Price($)"])

# %%
x = df[['Mileage','Age(yrs)']]
y = df["Sell Price($)"]

# %%
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.3)
#
# NameError: name 'train_test_split' is not defined

# %%
len(x_test)
x_test
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 17    69000         5
# 2     57000         5
# 0     69000         6
# 19    52000         5
# 1     35000         3

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     Mileage  Age(yrs)
# 3     22500         2
# 17    69000         5
# 2     57000         5
# 0     69000         6
# 19    52000         5
# 1     35000         3

# %%
clf.predict(x_test)
# Out:
# array([38738.68614105, 23418.67429547, 26403.55002151, 22167.46815974,
#        27647.24824069, 34378.23445736])

# %%
y_test
# Out:
# 3     40000
# 17    19700
# 2     26100
# 0     18000
# 19    28200
# 1     34000
# Name: Sell Price($), dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.9052841539849761
